# %%
import numpy as np
import pandas as pd
from ast import literal_eval
from Utils import *
import os
import cv2

# %%
crop_dir_path = "../data/images/cropped_images"
crop_bbox_path = "../data/annotations/all_crop_bbox_annotations.csv"

# %%
specific_crop = "P335976_1400_768_768.jpg"
image_path = f"{os.path.join(crop_dir_path, specific_crop)}"
img = cv2.imread(image_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
bbox_df = pd.read_csv(crop_bbox_path)
bbox_slice = bbox_df[bbox_df.image_path == specific_crop]
visualise_crops_with_bboxes(img=img, bbox_slice=bbox_slice)
